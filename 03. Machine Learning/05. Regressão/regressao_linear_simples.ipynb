# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"D:\donwloads\BaseDados_RegressaoLinear.xlsx")
df
# Out:
#         Salario  Limite_Emprestimo
# 0   1250.219130        2900.124323
# 1   1262.721321        2929.125566
# 2   1275.348535        2958.416822
# 3   1288.102020        2988.000990
# 4   1300.983040        3017.881000
# ..          ...                ...
# 94  3185.629581        7279.937858
# 95  3217.485877        7315.799621
# 96  3249.660736        7351.661384
# 97  3282.157343        7387.523147
# 98  3314.978916        7423.384910
#
# [99 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x = df.Salario.values
y = df.Limite_Emprestimo.values
plt.scatter(x, y)
plt.title('Correlação')
plt.xlabel('Salário')
plt.ylabel('Emprestimo')
plt.grid(True)
plt.show()

# %%
sns.pairplot(df)

# %%
x = df.Salario.values.reshape(-1, 1)
y = df.Limite_Emprestimo.values.reshape(-1, 1)

from sklearn.model_selection import train_test_split
x_treinamento,x_teste ,y_treinamento,y_test = train_test_split(
    x
    ,y
    ,test_size=0.3
)
x_treinamento
# Out:
# array([[1510.40092097],
#        [2771.3797703 ],
#        [1327.13279916],
#        [2559.322721  ],
#        [2056.15016548],
#        [2363.49159376],
#        [1603.32101309],
#        [1556.16757927],
#        [2293.98165561],
#        [1936.98646635],
#        [1956.35633102],
#        [1718.97713891],
#        [2508.89395255],
#        [1288.10201986],
#        [1313.99287046],
#        [2316.92147217],
#        [1995.67909327],
#        [1587.44654762],
#        [2226.51599446],
#        [1250.21913   ],
#        [2035.79224305],
#        [3001.00716811],
#        [2459.45883007],
#        [1340.40412715],
#        [2941.87547114],
#        [2827.08450368],
#        [1668.42227554],
#        [1525.50493018],
#        [2015.6358842 ],
#        [2204.47128165],
#        [2410.99777479],
#        [1788.77450385],
#        [2971.29422585],
#        [1736.1669103 ],
#        [2533.98289208],
#        [3122.86009317],
#        [2076.71166713],
#        [3031.01723979],
# ...

# %%
from sklearn.linear_model import LinearRegression

funcao = LinearRegression()
funcao.fit(x_treinamento, y_treinamento)
funcao.score(x_treinamento, y_treinamento)  # Avalia no mesmo conjunto
# Out:
# 0.9989580043420642

# %%
plt.scatter(x_treinamento, y_treinamento, label="Treinamento", color="blue")
plt.scatter(x_teste, y_test, label="Teste", color="green")
plt.plot(x_teste, funcao.predict(x_teste), color='red', label="Regressão")

plt.legend()
plt.title("Gráfico da Regressão Linear")
plt.xlabel("Salário")
plt.ylabel("Limite de Empréstimo")
plt.grid(True)
plt.show()
