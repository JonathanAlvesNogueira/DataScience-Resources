# %%
from sklearn.model_selection import train_test_split
# from sklearn.regression import LinearRegression
import numpy as np
import pandas as pd

# %%
import pandas as pd

data = {
    "renda_mensal": [2000, 3000, 4000, 5000, 6000, 7000, 8000, 3500, 4500, 5500],
    "idade": [25, 30, 35, 40, 45, 50, 30, 28, 33, 38],
    "score_credito": [500, 600, 650, 700, 750, 800, 720, 580, 640, 690],
    "valor_emprestimo": [8000, 12000, 15000, 20000, 25000, 30000, 27000, 13000, 17000, 22000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    renda_mensal  idade  score_credito  valor_emprestimo
# 0          2000     25            500              8000
# 1          3000     30            600             12000
# 2          4000     35            650             15000
# 3          5000     40            700             20000
# 4          6000     45            750             25000
# 5          7000     50            800             30000
# 6          8000     30            720             27000
# 7          3500     28            580             13000
# 8          4500     33            640             17000
# 9          5500     38            690             22000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()
